# %%
import pandas as pd

# %%
teams = pd.read_csv("../data/teams.csv")
matches = pd.read_csv("../data/matches.csv")
print(teams.head())
print(matches.head())
# Out:
#         team   elo winning_probability_percent
# 0      Spain  2155                      14.81%
# 1  Argentina  2113                       7.76%
# 2     France  2062                      14.30%
# 3    England  2021                      10.86%
# 4     Brazil  1991                       8.58%
#    match_id group         team1         team2  played  score1  score2
# 0         1     A        Mexico  South Africa   False     NaN     NaN
# 1         2     A        Mexico   South Korea   False     NaN     NaN
# 2         3     A        Mexico       Czechia   False     NaN     NaN
# 3         4     A  South Africa   South Korea   False     NaN     NaN
# 4         5     A  South Africa       Czechia   False     NaN     NaN
